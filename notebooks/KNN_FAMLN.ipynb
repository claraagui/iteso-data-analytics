# %% [markdown]
# KNN Titanic
# Programacion para el Analisis de Datos

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

df = pd.read_csv("../data/raw/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Family_size'] = df.SibSp + df.Parch+1
df['LastName'] = df['Name'].apply(lambda x: x.split(',')[0].strip())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
X = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked','Family_size','LastName']]
y = df['Survived']

X.isnull().sum()
# Out:
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# Family_size      0
# LastName         0
# dtype: int64

# %%
#Reemplazar datos faltantes
X['Age'].fillna(X['Age'].median(), inplace=True)
X['Fare'].fillna(X['Fare'].median(), inplace=True)
X['Embarked'].fillna(X['Embarked'].mode()[0], inplace=True)  


X = pd.get_dummies(X, columns=['Sex', 'Embarked','LastName'], drop_first=True)
# Out:
# C:\Users\Aissa\AppData\Local\Temp\ipykernel_26600\1098644564.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Age'].fillna(X['Age'].median(), inplace=True)
# C:\Users\Aissa\AppData\Local\Temp\ipykernel_26600\1098644564.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Fare'].fillna(X['Fare'].median(), inplace=True)
# C:\Users\Aissa\AppData\Local\Temp\ipykernel_26600\1098644564.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Estandarizar los features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Modelo KNN
knn = KNeighborsClassifier(metric='cosine')
knn.fit(X_train, y_train)

# Predecir la y
y_pred = knn.predict(X_test)

# Evaluar el modelo
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6759776536312849

# %%
# Modelo KNN
knn = KNeighborsClassifier(metric='euclidean')
knn.fit(X_train, y_train)

# Predecir la y
y_pred = knn.predict(X_test)

# Evaluar el modelo
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6368715083798883

# %% [markdown]
# # Test 01

# %%
test_df= pd.read_csv("../data/raw/train.csv")

test_df['Family_size'] = test_df.SibSp + df.Parch+1
test_df['LastName'] = test_df['Name'].apply(lambda x: x.split(',')[0].strip())
test_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test_X = test_df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'Family_size','LastName',]]

# %%
test_X['Age'].fillna(test_X['Age'].median(), inplace=True)
test_X['Fare'].fillna(test_X['Fare'].median(), inplace=True)
test_X['Embarked'].fillna(test_X['Embarked'].mode()[0], inplace=True)  # Fill missing values with the most common value
# Out:
# C:\Users\Aissa\AppData\Local\Temp\ipykernel_26600\3021871352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_X['Age'].fillna(test_X['Age'].median(), inplace=True)
# C:\Users\Aissa\AppData\Local\Temp\ipykernel_26600\3021871352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_X['Fare'].fillna(test_X['Fare'].median(), inplace=True)
# C:\Users\Aissa\AppData\Local\Temp\ipykernel_26600\3021871352.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
test_X = pd.get_dummies(test_X, columns=['Sex', 'Embarked','LastName'], drop_first=True)
test_X = scaler.transform(test_X)
test_y_pred = knn.predict(test_X)

# %%
test_predictions = pd.DataFrame({'PassengerId': test_df['PassengerId'], 'Survived': test_y_pred})
test_predictions.to_csv(path_or_buf= "../data/processed/titanic_submission2.csv")
